# %% [markdown]
# # Training Agent, action converters and l2rpn_baselines
# Try me out interactively with: [![Binder](./img/badge_logo.svg)](https://mybinder.org/v2/gh/Grid2Op/grid2op/master)

# %% [markdown]
# It is recommended to have a look at the [00_SmallExample](00_SmallExample.ipynb), [02_Observation](02_Observation.ipynb) and [03_Action](03_Action.ipynb) notebooks before getting into this one.

# %% [markdown]
# **Objectives**
#
# In this notebook we will expose :
# * how to  make grid2op compatible with *gym* RL framework (short introduction to *gym_compat* module)
# * how to transform grid2op actions / observations with gym "spaces" (https://gym.openai.com/docs/#spaces)
# * how to train a (naive) Agent using reinforcement learning.
# * how to inspect (rapidly) the actions taken by the Agent.
#
# **NB** In this tutorial, we will use the
#
# <font size="3" color="red">This notebook do not cover the use of existing RL frameworks. Please consult the [11_IntegrationWithExistingRLFrameworks](11_IntegrationWithExistingRLFrameworks.ipynb) for such information! </font>
#
#
# **Don't hesitate to check the grid2op module grid2op.gym_compat for a closer integration between grid2op and openAI gym. This module is documented at https://grid2op.readthedocs.io/en/latest/gym.html**

# %% [markdown]
# <img src="https://colab.research.google.com/assets/colab-badge.svg" width="200">
# Execute the cell below by removing the # character if you use google colab !
#
# Cell will look like:
# ```python
# !pip install grid2op[optional]  # for use with google colab (grid2op is not installed by default)
# ```
# <img src="https://colab.research.google.com/assets/colab-badge.svg" width="200">

# %%
# !pip install grid2op[optional]  # for use with google colab (grid2Op is not installed by default)

# %%
import os
import sys
LEARNING_ITERATION = 50
EVAL_EPISODE = 1
MAX_EVAL_STEPS = 10

# %%
res = None
try:
    from jyquickhelper import add_notebook_menu
    res = add_notebook_menu()
except ModuleNotFoundError:
    print("Impossible to automatically add a menu / table of content to this notebook.\nYou can download \"jyquickhelper\" package with: \n\"pip install jyquickhelper\"")
res
# Out:
# <div id="my_id_menu_nb">run previous cell, wait for 2 seconds</div>
# <script>
# function repeat_indent_string(n){
#     var a = "" ;
#     for ( ; n > 0 ; --n)
#         a += "    ";
#     return a;
# }
# // look up into all sections and builds an automated menu //
# var update_menu_string = function(begin, lfirst, llast, sformat, send, keep_item, begin_format, end_format) {
#     var anchors = document.getElementsByClassName("section");
#     if (anchors.length == 0) {
#         anchors = document.getElementsByClassName("text_cell_render rendered_html");
#     }
#     var i,t;
#     var text_menu = begin;
#     var text_memo = "<pre>\nlength:" + anchors.length + "\n";
#     var ind = "";
#     var memo_level = 1;
#     var href;
#     var tags = [];
#     var main_item = 0;
#     var format_open = 0;
#     for (i = 0; i <= llast; i++)
#         tags.push("h" + i);
#
#     for (i = 0; i < anchors.length; i++) {
#         text_memo += "**" + anchors[i].id + "--\n";
#
#         var child = null;
#         for(t = 0; t < tags.length; t++) {
#             var r = anchors[i].getElementsByTagName(tags[t]);
#             if (r.length > 0) {
# child = r[0];
# break;
#             }
#         }
#         if (child == null) {
#             text_memo += "null\n";
#             continue;
#         }
#         if (anchors[i].hasAttribute("id")) {
#             // when converted in RST
#             href = anchors[i].id;
#             text_memo += "#1-" + href;
#             // passer à child suivant (le chercher)
#         }
#         else if (child.hasAttribute("id")) {
#             // in a notebook
#             href = child.id;
#             text_memo += "#2-" + href;
#         }
#         else {
#             text_memo += "#3-" + "*" + "\n";
#             continue;
#         }
#         var title = child.textContent;
#         var level = parseInt(child.tagName.substring(1,2));
#
#         text_memo += "--" + level + "?" + lfirst + "--" + title + "\n";
#
#         if ((level < lfirst) || (level > llast)) {
#             continue ;
#         }
#         if (title.endsWith('¶')) {
#             title = title.substring(0,title.length-1).replace("<", "&lt;")
#          .replace(">", "&gt;").replace("&", "&amp;");
#         }
#         if (title.length == 0) {
#             continue;
#         }
#
#         while (level < memo_level) {
#             text_menu += end_format + "</ul>\n";
#             format_open -= 1;
#             memo_level -= 1;
#         }
#         if (level == lfirst) {
#             main_item += 1;
#         }
#         if (keep_item != -1 && main_item != keep_item + 1) {
#             // alert(main_item + " - " + level + " - " + keep_item);
#             continue;
#         }
#         while (level > memo_level) {
#             text_menu += "<ul>\n";
#             memo_level += 1;
#         }
#         text_menu += repeat_indent_string(level-2);
#         text_menu += begin_format + sformat.replace("__HREF__", href).replace("__TITLE__", title);
#         format_open += 1;
#     }
#     while (1 < memo_level) {
#         text_menu += end_format + "</ul>\n";
#         memo_level -= 1;
#         format_open -= 1;
#     }
#     text_menu += send;
#     //text_menu += "\n" + text_memo;
#
#     while (format_open > 0) {
#         text_menu += end_format;
#         format_open -= 1;
#     }
#     return text_menu;
# };
# var update_menu = function() {
#     var sbegin = "";
#     var sformat = '<a href="#__HREF__">__TITLE__</a>';
#     var send = "";
#     var begin_format = '<li>';
#     var end_format = '</li>';
#     var keep_item = -1;
#     var text_menu = update_menu_string(sbegin, 2, 4, sformat, send, keep_item,
#        begin_format, end_format);
#     var menu = document.getElementById("my_id_menu_nb");
#     menu.innerHTML=text_menu;
# };
# window.setTimeout(update_menu,2000);
#             </script>

# %% [markdown]
# ## 0) Good practice
#
# ### A. defining a training, validation and test sets
#
# As in other machine learning tasks, we highly recommend, before even trying to train an agent, to split the the "episode data" (*eg* what are the loads / generations for each load / generator) into 3 datasets:
# - "train" use to train the agent
# - "val" use to validate the hyper parameters
# - "test" at which you would look **only once** to report the agent performance in a scientific paper (for example)
#
# Grid2op lets you do that with relative ease:
#
# ```python
# import grid2op
# env_name = "l2rpn_case14_sandbox"  # or any other...
# env = grid2op.make(env_name)
#
# # extract 1% of the "chronics" to be used in the validation environment. The other 99% will
# # be used for test
# nm_env_train, nm_env_val, nm_env_test = env.train_val_split_random(pct_val=1., pct_test=1.)
#
# # and now you can use the training set only to train your agent:
# print(f"The name of the training environment is \\"{nm_env_train}\\"")
# print(f"The name of the validation environment is \\"{nm_env_val}\\"")
# print(f"The name of the test environment is \\"{nm_env_test}\\"")
# ```

# %% [markdown]
# And now, you can use the training environment to train your agent:
#
# ```python
# import grid2op
# env_name = "l2rpn_case14_sandbox"
# env = grid2op.make(env_name+"_train")
# ```
#
# Be carefull, on windows you might run into issues. Don't hesitate to have a look at the documentation of this funciton if this the case (see https://grid2op.readthedocs.io/en/latest/environment.html#grid2op.Environment.Environment.train_val_split and https://grid2op.readthedocs.io/en/latest/environment.html#grid2op.Environment.Environment.train_val_split_random)
#
# ### B. Not spending all of your time loading data...
#
# In most grid2op environment, the "data" are loaded from the hard drive.
#
# From experience, what happens (especially at the beginning of training) is that your agent survives a few steps (so taking a few milliseconds) before a game over. At this stage you will call `env.reset()` which will load the data of the next scenario.
#
# This is the default behaviour and it is far from "optimal" (more time is spent loading data than performing actual useful computation). To that end, we encourage you:
# - to use a "caching" mechanism, for example with `MultifolderWithCache` class
# - to read the data by small "chunk" (`env.chronics_handler.set_chunk_size(...)`).
#
# More information is provided in https://grid2op.readthedocs.io/en/latest/environment.html#optimize-the-data-pipeline
#
# ### C. Use a fast simulator
#
# Grid2op will use a "backend" to compute the powerflows and be able to return the next observation (after `env.step(...)`). These "backends" can be faster. For example, we strongly encourage you to use the "lightsim2grid" backend.
#
# You can install it with `pip install lightsim2grid`
#
# And use it with:
# ```python
# import grid2op
# from lightsim2grid import LightSimBackend
# env_name = "l2rpn_case14_sandbox"
# env = grid2op.make(env_name+"_train", backend=LightSimBackend(), ...)
# ```

# %% [markdown]
# ## I) Action representation

# %% [markdown]
# ### What's this ?
#
# The Grid2op package has been built with an "object-oriented" perspective: almost everything is encapsulated in a dedicated `class`. This allows for more customization of the plateform.
#
# The downside of this approach is that machine learning methods, especially in deep learning, often prefer to deal with vectors rather than with "complex" objects. Indeed, as we covered in the previous tutorials on the platform, we saw that building our own actions can be tedious and can sometime require important knowledge of the powergrid.
#
# On the contrary, in most of the standard Reinforcement Learning environments, actions have a higher level representation. For example in pacman, there are 4 different types of actions: "turn left", "turn right", "go up" and "go down". This allows for easy sampling (if you need to achieve an uniform sampling, you simply need to randomly pick a number between 0 and 3 included) and an easy representation: each action can be represented as a different component of a vector of dimension 4 [because there are 4 actions].
#
# On the other hand, this representation is not "human friendly". It is quite convenient in the case of pacman because the action space is rather small, making it possible to remember which action corresponds to which component, but in the case of the grid2op package, there are hundreds or even thousands of actions. We suppose that we do not really care about this here, as tutorials on Reinforcement Learning with discrete action space often assume that actions are labeled with integers (such as in pacman for example).
#
# Converting grid2op actions into "machine readable" ones is the major difficulty as there is no unique ways to do so. In grid2op we offer some pre defined "functions" to do so:
#
# - `BoxGymObsSpace` will convert the action space into a gym "Box". It is rather straightforward, especially for **continuous** type of actions (such as *redispatching*, *curtailment* or actions on *storage units*). Representing the discrete actions (on powerlines and on substation) is not an easy task with them. We would not recommend to use them if your focus is on topology. More information on https://grid2op.readthedocs.io/en/latest/gym.html#grid2op.gym_compat.BoxGymActSpace
# - `MultiDiscreteActSpace` is similar to `BoxGymObsSpace` but mainly focused on the **discrete** actions (*lines status* and *substation reconfiguration*). Actions are represented with a gym "MultiDiscrete" space. It allows to perform any number of actions you want (which might be illegal) but comes with little restrictions. It handles continuous actions through "binning" (which is not ideal but doable). We recommend using this transformation if the algorithm you want to use is able to deal with "MultiDiscrete" gym action type. More information is given at https://grid2op.readthedocs.io/en/latest/gym.html#grid2op.gym_compat.MultiDiscreteActSpace
# - `DiscreteActSpace` is similar to `MultiDiscreteActSpace` in the sense that it focuses on **discrete** actions. It comes with a main restriction though: you can only do one action. For example, you cannot "modify a substation" AND "disconnect a powerline" with the same action. More information is provided at https://grid2op.readthedocs.io/en/latest/gym.html#grid2op.gym_compat.DiscreteActSpace. We recommend to use it if you want to focus on **discrete** actions and the algorithm you want to use is not able to deal with `MultiDiscreteActSpace`.
# - You can also fully customize the way you "represent" the action. More information is given in the notebook [11_IntegrationWithExistingRLFrameworks](11_IntegrationWithExistingRLFrameworks.ipynb)
#
# In the next section we will show an agent working with `DiscreteActSpace`. The code showed can be easily adapted with the other type of actions.
#
# ### Create a gym compatible environment
#
# The first step is to "convert" your environment into a gym environment, for easier manipulation.

# %%
from grid2op.gym_compat import GymEnv
import grid2op
from gymnasium import Env
from gymnasium.utils.env_checker import check_env
try:
    from lightsim2grid import LightSimBackend
    bk_cls = LightSimBackend
except ImportError as exc:
    print(f"Error: {exc} when importing faster LightSimBackend")
    from grid2op.Backend import PandaPowerBackend
    bk_cls = PandaPowerBackend
    
# l2rpn_case14_sandbox   or  educ_case14_storage

env_name = "educ_case14_storage" 
training_env = grid2op.make(env_name, test=True, backend=bk_cls())  # we put "test=True" in this notebook because...
# it's a notebook to explain things. Of course, do not put "test=True" if you really want
# to train an agent...
gym_env = GymEnv(training_env)
# Out:
# c:\Users\admin\Grid2Op\venv_g2op\lib\site-packages\grid2op\Backend\pandaPowerBackend.py:36: UserWarning: Numba cannot be loaded. You will gain possibly massive speed if installing it by
# 	c:\Users\admin\Grid2Op\venv_g2op\Scripts\python.exe -m pip install numba
#
#   warnings.warn(
# c:\Users\admin\Grid2Op\venv_g2op\lib\site-packages\grid2op\MakeEnv\Make.py:454: UserWarning: You are using a development environment. This environment is not intended for training agents. It might not be up to date and its primary use if for tests (hence the "test=True" you passed as argument). Use at your own risk.
#   warnings.warn(_MAKE_DEV_ENV_WARN)

# %%
isinstance(gym_env, Env)
# Out:
# True

# %%
check_env(gym_env, warn=False)
# Out:
# c:\Users\admin\Grid2Op\venv_g2op\lib\site-packages\gymnasium\utils\env_checker.py:367: UserWarning: WARN: `check_env(warn=...)` parameter is now ignored.
#   logger.warn("`check_env(warn=...)` parameter is now ignored.")
# c:\Users\admin\Grid2Op\venv_g2op\lib\site-packages\gymnasium\utils\passive_env_checker.py:54: UserWarning: WARN: A Box action space maximum and minimum values are equal.
#   logger.warn("A Box action space maximum and minimum values are equal.")
# c:\Users\admin\Grid2Op\venv_g2op\lib\site-packages\gymnasium\utils\env_checker.py:333: UserWarning: WARN: For Box action spaces, we recommend using a symmetric and normalized space (range=[-1, 1] or [0, 1]). See https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html for more information.
#   logger.warn(
# c:\Users\admin\Grid2Op\venv_g2op\lib\site-packages\gymnasium\utils\passive_env_checker.py:35: UserWarning: WARN: A Box observation space maximum and minimum values are equal.
#   logger.warn("A Box observation space maximum and minimum values are equal.")
# c:\Users\admin\Grid2Op\venv_g2op\lib\site-packages\gymnasium\utils\env_checker.py:311: UserWarning: WARN: A Box observation space minimum value is -infinity. This is probably too low.
#   logger.warn(
# c:\Users\admin\Grid2Op\venv_g2op\lib\site-packages\gymnasium\utils\env_checker.py:315: UserWarning: WARN: A Box observation space maximum value is infinity. This is probably too high.
#   logger.warn(
# c:\Users\admin\Grid2Op\venv_g2op\lib\site-packages\gymnasium\utils\env_checker.py:434: UserWarning: WARN: Not able to test alternative render modes due to the environment not having a spec. Try instantiating the environment through `gymnasium.make`
#   logger.warn(

# %% [markdown]
# As you can see, `gym_env` is really an environment from gym. It also meets the gym requirements and pass the checks performed by gym.
#
# By default however, the action space and observation space are Dictionnaries, which is not convenient for most machine learning algorithm (they need to be transformed into vectors somehow).

# %%
gym_env.action_space
# Out:
# Dict('change_line_status': MultiBinary(20), 'redispatch': Box([ -5. -10.   0.   0.   0. -15.], [ 5. 10.  0.  0.  0. 15.], (6,), float32), 'set_storage': Box([ -5. -10.], [ 5. 10.], (2,), float32))

# %%
gym_env.action_space.spaces
# Out:
# {'change_line_status': MultiBinary(20),
#  'redispatch': Box([ -5. -10.   0.   0.   0. -15.], [ 5. 10.  0.  0.  0. 15.], (6,), float32),
#  'set_storage': Box([ -5. -10.], [ 5. 10.], (2,), float32)}

# %%
gym_env.observation_space.spaces
# Out:
# {'_shunt_bus': Box(-2147483648, 2147483647, (1,), int32),
#  '_shunt_p': Box(-inf, inf, (1,), float32),
#  '_shunt_q': Box(-inf, inf, (1,), float32),
#  '_shunt_v': Box(-inf, inf, (1,), float32),
#  'a_ex': Box(0.0, inf, (20,), float32),
#  'a_or': Box(0.0, inf, (20,), float32),
#  'actual_dispatch': Box([-140. -120.  -70.  -70.  -40. -100.], [140. 120.  70.  70.  40. 100.], (6,), float32),
#  'attention_budget': Box(0.0, inf, (1,), float32),
#  'current_step': Box(-2147483648, 2147483647, (1,), int32),
#  'curtailment': Box(0.0, 1.0, (6,), float32),
#  'curtailment_limit': Box(0.0, 1.0, (6,), float32),
#  'curtailment_limit_effective': Box(0.0, 1.0, (6,), float32),
#  'day': Discrete(32),
#  'day_of_week': Discrete(8),
#  'delta_time': Box(0.0, inf, (1,), float32),
#  'duration_next_maintenance': Box(-1, 2147483647, (20,), int32),
#  'gen_margin_down': Box(0.0, [ 5. 10.  0.  0.  0. 15.], (6,), float32),
#  'gen_margin_up': Box(0.0, [ 5. 10.  0.  0.  0. 15.], (6,), float32),
#  'gen_p': Box(-162.01, [302.01    282.01    232.01001 232.01001 202.01    262.01   ], (6,), float32),
#  'gen_p_before_curtail': Box(-162.01, [302.01    282.01    232.01001 232.01001 202.01    262.01   ], (6,), float32),
#  'gen_q': Box(-inf, inf, (6,), float32),
#  'gen_theta': Box(-180.0, 180.0, (6,), float32),
#  'gen_v': Box(0.0, inf, (6,), float32),
#  'hour_of_day': Discrete(24),
#  'is_alarm_illegal': Discrete(2),
#  'line_status': MultiBinary(20),
#  'load_p': Box(-inf, inf, (11,), float32),
#  'load_q': Box(-inf, inf, (11,), float32),
#  'load_theta': Box(-180.0, 180.0, (11,), float32),
#  'load_v': Box(0.0, inf, (11,), float32),
#  'max_step': Box(-2147483648, 2147483647, (1,), int32),
#  'minute_of_hour': Discrete(60),
#  'month': Discrete(13),
#  'p_ex': Box(-inf, inf, (20,), float32),
#  'p_or': Box(-inf, inf, (20,), float32),
#  'q_ex': Box(-inf, inf, (20,), float32),
#  'q_or': Box(-inf, inf, (20,), float32),
#  'rho': Box(0.0, inf, (20,), float32),
#  'storage_charge': Box(0.0, [15.  7.], (2,), float32),
#  'storage_power': Box([ -5. -10.], [ 5. 10.], (2,), float32),
#  'storage_power_target': Box([ -5. -10.], [ 5. 10.], (2,), float32),
#  'storage_theta': Box(-180.0, 180.0, (2,), float32),
#  'target_dispatch': Box([-140. -120.  -70.  -70.  -40. -100.], [140. 120.  70.  70.  40. 100.], (6,), float32),
#  'thermal_limit': Box(0.0, inf, (20,), float32),
#  'theta_ex': Box(-180.0, 180.0, (20,), float32),
#  'theta_or': Box(-180.0, 180.0, (20,), float32),
#  'time_before_cooldown_line': Box(0, 12, (20,), int32),
#  'time_before_cooldown_sub': Box(0, 3, (14,), int32),
#  'time_next_maintenance': Box(-1, 2147483647, (20,), int32),
#  'time_since_last_alarm': Box(-1, 2147483647, (1,), int32),
#  'timestep_overflow': Box(-2147483648, 2147483647, (20,), int32),
#  'topo_vect': Box(-1, 2, (59,), int32),
#  'v_ex': Box(0.0, inf, (20,), float32),
#  'v_or': Box(0.0, inf, (20,), float32),
#  'was_alarm_used_after_game_over': Discrete(2),
#  'year': Discrete(2100)}

# %%
gym_env.observation_space
# Out:
# Dict('_shunt_bus': Box(-2147483648, 2147483647, (1,), int32), '_shunt_p': Box(-inf, inf, (1,), float32), '_shunt_q': Box(-inf, inf, (1,), float32), '_shunt_v': Box(-inf, inf, (1,), float32), 'a_ex': Box(0.0, inf, (20,), float32), 'a_or': Box(0.0, inf, (20,), float32), 'actual_dispatch': Box([-140. -120.  -70.  -70.  -40. -100.], [140. 120.  70.  70.  40. 100.], (6,), float32), 'attention_budget': Box(0.0, inf, (1,), float32), 'current_step': Box(-2147483648, 2147483647, (1,), int32), 'curtailment': Box(0.0, 1.0, (6,), float32), 'curtailment_limit': Box(0.0, 1.0, (6,), float32), 'curtailment_limit_effective': Box(0.0, 1.0, (6,), float32), 'day': Discrete(32), 'day_of_week': Discrete(8), 'delta_time': Box(0.0, inf, (1,), float32), 'duration_next_maintenance': Box(-1, 2147483647, (20,), int32), 'gen_margin_down': Box(0.0, [ 5. 10.  0.  0.  0. 15.], (6,), float32), 'gen_margin_up': Box(0.0, [ 5. 10.  0.  0.  0. 15.], (6,), float32), 'gen_p': Box(-162.01, [302.01    282.01    232.01001 232.01001 202.01    262.01   ], (6,), float32), 'gen_p_before_curtail': Box(-162.01, [302.01    282.01    232.01001 232.01001 202.01    262.01   ], (6,), float32), 'gen_q': Box(-inf, inf, (6,), float32), 'gen_theta': Box(-180.0, 180.0, (6,), float32), 'gen_v': Box(0.0, inf, (6,), float32), 'hour_of_day': Discrete(24), 'is_alarm_illegal': Discrete(2), 'line_status': MultiBinary(20), 'load_p': Box(-inf, inf, (11,), float32), 'load_q': Box(-inf, inf, (11,), float32), 'load_theta': Box(-180.0, 180.0, (11,), float32), 'load_v': Box(0.0, inf, (11,), float32), 'max_step': Box(-2147483648, 2147483647, (1,), int32), 'minute_of_hour': Discrete(60), 'month': Discrete(13), 'p_ex': Box(-inf, inf, (20,), float32), 'p_or': Box(-inf, inf, (20,), float32), 'q_ex': Box(-inf, inf, (20,), float32), 'q_or': Box(-inf, inf, (20,), float32), 'rho': Box(0.0, inf, (20,), float32), 'storage_charge': Box(0.0, [15.  7.], (2,), float32), 'storage_power': Box([ -5. -10.], [ 5. 10.], (2,), float32), 'storage_power_target': Box([ -5. -10.], [ 5. 10.], (2,), float32), 'storage_theta': Box(-180.0, 180.0, (2,), float32), 'target_dispatch': Box([-140. -120.  -70.  -70.  -40. -100.], [140. 120.  70.  70.  40. 100.], (6,), float32), 'thermal_limit': Box(0.0, inf, (20,), float32), 'theta_ex': Box(-180.0, 180.0, (20,), float32), 'theta_or': Box(-180.0, 180.0, (20,), float32), 'time_before_cooldown_line': Box(0, 12, (20,), int32), 'time_before_cooldown_sub': Box(0, 3, (14,), int32), 'time_next_maintenance': Box(-1, 2147483647, (20,), int32), 'time_since_last_alarm': Box(-1, 2147483647, (1,), int32), 'timestep_overflow': Box(-2147483648, 2147483647, (20,), int32), 'topo_vect': Box(-1, 2, (59,), int32), 'v_ex': Box(0.0, inf, (20,), float32), 'v_or': Box(0.0, inf, (20,), float32), 'was_alarm_used_after_game_over': Discrete(2), 'year': Discrete(2100))

# %% [markdown]
# This is why it is often a good idea to customize the environment to have proper observations and actions.
#
# This is covered more in depth on the notebook [11_IntegrationWithExistingRLFrameworks](11_IntegrationWithExistingRLFrameworks.ipynb) (especially for the observation space).
#
# Here we use simple converters to focus on the training of the agent. You can set them with:

# %%
from grid2op.gym_compat import DiscreteActSpace
gym_env.action_space = DiscreteActSpace(training_env.action_space,
                                        attr_to_keep=["set_bus" , "set_line_status_simple"])
gym_env.action_space
# Out:
# c:\Users\admin\Grid2Op\venv_g2op\lib\site-packages\grid2op\Action\playableAction.py:141: UserWarning: The key "set_bus" used to update an action will be ignored. Valid keys are {'set_storage', 'change_line_status', 'redispatch'}
#   warnings.warn(warn)
# c:\Users\admin\Grid2Op\venv_g2op\lib\site-packages\grid2op\Action\playableAction.py:141: UserWarning: The key "set_line_status" used to update an action will be ignored. Valid keys are {'set_storage', 'change_line_status', 'redispatch'}
#   warnings.warn(warn)
# Discrete(275)

# %%
from grid2op.gym_compat import BoxGymObsSpace
gym_env.observation_space = BoxGymObsSpace(training_env.observation_space,
                                           attr_to_keep=["rho"])
gym_env.observation_space
# Out:
# Box(0.0, inf, (20,), float32)

# %% [markdown]
# And now your agent will receive a "box" as observation:

# %%
obs = gym_env.reset()
obs
# Out:
# (array([0.33181158, 0.3045546 , 0.34508008, 0.236113  , 0.6555203 ,
#         0.18013322, 0.46848553, 0.7580641 , 0.5982698 , 0.9056341 ,
#         0.21540143, 0.30127925, 0.45351976, 0.55273116, 0.53557587,
#         0.4355288 , 0.40401933, 0.38086173, 0.4900764 , 0.3861611 ],
#        dtype=float32),
#  {'time serie id': 'c:\\Users\\admin\\Grid2Op\\venv_g2op\\lib\\site-packages\\grid2op\\data\\educ_case14_storage\\chronics\\2019-01-17'})

# %% [markdown]
# And will be able to interact with the environment with standard "int" (integers that are the normal way to represent "Discrete" gym space)

# %%
obs, reward, terminated, truncated, info = gym_env.step(0)  # perform action labeled 0
obs
# Out:
# array([0.32135937, 0.3000506 , 0.34235212, 0.23478776, 0.6519148 ,
#        0.1810932 , 0.46595392, 0.7635492 , 0.60243726, 0.9123861 ,
#        0.21305034, 0.3105899 , 0.4579591 , 0.5569603 , 0.5440609 ,
#        0.43236494, 0.3993437 , 0.3661306 , 0.49106917, 0.38275287],
#       dtype=float32)

# %%
obs, reward, terminated, truncated, info = gym_env.step(53)  # perform action labeled 53
obs
# Out:
# array([0.32412845, 0.30069134, 0.34703228, 0.23522784, 0.6507118 ,
#        0.1785905 , 0.47194532, 0.76733917, 0.60522026, 0.9124757 ,
#        0.2169281 , 0.29950812, 0.46248776, 0.54979986, 0.5387624 ,
#        0.43029606, 0.39776206, 0.35863146, 0.4904536 , 0.38242292],
#       dtype=float32)

# %% [markdown]
# ### Even better gym environment
# The environment show here directly "maps" a grid2op environment to a gym environment: at each "grid2op step" the agent is asked to chose an action.
#
#
# After a few itérations of the "l2rpn" competitions it appears that the vast majority of top performers all rely on "heuristics" to handle the problem showed in grid2op.
#
# For example, most of the time the "agent" does not take any actions when all the flows are bellow a certain threshold (say 90%) and only do actions when at least one powerline sees a flow above this limit.
#
# In `l2rpn_baselines` we embeded directly the possibility to have a "gym environment" that does some of these heuristics. For example, the "gym environment" keeps performing "steps" (with the do nothing action) while all the flows are bellow a certain threshold. Otherwise it asks for an action at the agent. In this setting, the agent is directly trained with the heuristics used at inference time.
#
# This is available in:
#
# ```python
# from l2rpn_baselines.utils import GymEnvWithReco, GymEnvWithRecoWithDN
# ```

# %% [markdown]
# ## II) Train an Agent
#
# In this tutorial we will train an agent that uses only discrete actions thanks to the "stable baselines 3" RL package.
#
# More precisely, we will use the "PPO" algorithm. We do not cover the details of such algorithm here.
#
# **NB** here we show a minimal complete code to get started. We recommend however to use the l2rpn_baselines `PPO_SB3` model (that integrates all this, which much better customization) for such purpose.

# %%
from stable_baselines3 import PPO
nn_model = PPO(env=gym_env,
               learning_rate=1e-3,
               policy="MlpPolicy",
               policy_kwargs={"net_arch": [100, 100, 100]},
               n_steps=2,
               batch_size=8,
               verbose=True, 
               device = "cpu"
               )
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Users\admin\Grid2Op\venv_g2op\lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 8, but because the `RolloutBuffer` is of size `n_steps * n_envs = 2`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 2
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=2 and n_envs=1)
#   warnings.warn(

# %%
nn_model.learn(total_timesteps=6666)
#LEARNING_ITERATION
# Out:
# ---------------------------
# | time/              |    |
# |    fps             | 44 |
# |    iterations      | 1  |
# |    time_elapsed    | 0  |
# |    total_timesteps | 2  |
# ---------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 27        |
# |    iterations           | 2         |
# |    time_elapsed         | 0         |
# |    total_timesteps      | 4         |
# | train/                  |           |
# |    approx_kl            | 0.2152648 |
# |    clip_fraction        | 0.7       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.52     |
# |    explained_variance   | 3.03e-05  |
# |    learning_rate        | 0.001     |
# |    loss                 | 249       |
# |    n_updates            | 260       |
# |    policy_gradient_loss | -0.111    |
# |    value_loss           | 517       |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 3          |
# |    time_elapsed         | 0          |
# |    total_timesteps      | 6          |
# | train/                  |            |
# |    approx_kl            | 0.32582948 |
# |    clip_fraction        | 0.7        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.49      |
# |    explained_variance   | 1.08e-05   |
# |    learning_rate        | 0.001      |
# |    loss                 | 249        |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.115     |
# |    value_loss           | 517        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 26         |
# |    iterations           | 4          |
# |    time_elapsed         | 0          |
# |    total_timesteps      | 8          |
# | train/                  |            |
# |    approx_kl            | 0.36036515 |
# |    clip_fraction        | 0.7        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.46      |
# |    explained_variance   | 1.13e-05   |
# |    learning_rate        | 0.001      |
# |    loss                 | 249        |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.116     |
# |    value_loss           | 519        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 24         |
# |    iterations           | 5          |
# |    time_elapsed         | 0          |
# |    total_timesteps      | 10         |
# | train/                  |            |
# |    approx_kl            | 0.38077658 |
# |    clip_fraction        | 0.7        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.45      |
# |    explained_variance   | 3.64e-05   |
# |    learning_rate        | 0.001      |
# |    loss                 | 255        |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.117     |
# |    value_loss           | 531        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 6          |
# |    time_elapsed         | 0          |
# |    total_timesteps      | 12         |
# | train/                  |            |
# |    approx_kl            | 0.39203626 |
# |    clip_fraction        | 0.7        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.44      |
# |    explained_variance   | 4.16e-05   |
# |    learning_rate        | 0.001      |
# |    loss                 | 263        |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.117     |
# |    value_loss           | 546        |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 21        |
# |    iterations           | 7         |
# |    time_elapsed         | 0         |
# |    total_timesteps      | 14        |
# | train/                  |           |
# |    approx_kl            | 0.4018877 |
# |    clip_fraction        | 0.7       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.43     |
# |    explained_variance   | 2.83e-05  |
# |    learning_rate        | 0.001     |
# |    loss                 | 268       |
# |    n_updates            | 310       |
# |    policy_gradient_loss | -0.117    |
# |    value_loss           | 557       |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 8          |
# |    time_elapsed         | 0          |
# |    total_timesteps      | 16         |
# | train/                  |            |
# |    approx_kl            | 0.26365048 |
# |    clip_fraction        | 0.7        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.41      |
# |    explained_variance   | 1.14e-05   |
# |    learning_rate        | 0.001      |
# |    loss                 | 273        |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.113     |
# |    value_loss           | 566        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 9          |
# |    time_elapsed         | 0          |
# |    total_timesteps      | 18         |
# | train/                  |            |
# |    approx_kl            | 0.25158408 |
# |    clip_fraction        | 0.7        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.38      |
# |    explained_variance   | 3.04e-06   |
# |    learning_rate        | 0.001      |
# |    loss                 | 274        |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.111     |
# |    value_loss           | 568        |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 22        |
# |    iterations           | 10        |
# |    time_elapsed         | 0         |
# |    total_timesteps      | 20        |
# | train/                  |           |
# |    approx_kl            | 0.2744503 |
# |    clip_fraction        | 0.75      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.37     |
# |    explained_variance   | 2.67e-05  |
# |    learning_rate        | 0.001     |
# |    loss                 | 276       |
# |    n_updates            | 340       |
# |    policy_gradient_loss | -0.115    |
# |    value_loss           | 573       |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 11         |
# |    time_elapsed         | 0          |
# |    total_timesteps      | 22         |
# | train/                  |            |
# |    approx_kl            | 0.31817818 |
# |    clip_fraction        | 0.75       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.38      |
# |    explained_variance   | -2.62e-06  |
# |    learning_rate        | 0.001      |
# |    loss                 | 276        |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.118     |
# |    value_loss           | 573        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 12         |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 24         |
# | train/                  |            |
# |    approx_kl            | 0.38277763 |
# |    clip_fraction        | 0.7        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.33      |
# |    explained_variance   | -1.03e-05  |
# |    learning_rate        | 0.001      |
# |    loss                 | 276        |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.115     |
# |    value_loss           | 573        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 13         |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 26         |
# | train/                  |            |
# |    approx_kl            | 0.36685595 |
# |    clip_fraction        | 0.8        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.22      |
# |    explained_variance   | 6.62e-06   |
# |    learning_rate        | 0.001      |
# |    loss                 | 276        |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.119     |
# |    value_loss           | 573        |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 22        |
# |    iterations           | 14        |
# |    time_elapsed         | 1         |
# |    total_timesteps      | 28        |
# | train/                  |           |
# |    approx_kl            | 0.3753953 |
# |    clip_fraction        | 0.75      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.17     |
# |    explained_variance   | 1.85e-05  |
# |    learning_rate        | 0.001     |
# |    loss                 | 278       |
# |    n_updates            | 380       |
# |    policy_gradient_loss | -0.117    |
# |    value_loss           | 577       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 22        |
# |    iterations           | 15        |
# |    time_elapsed         | 1         |
# |    total_timesteps      | 30        |
# | train/                  |           |
# |    approx_kl            | 0.3997447 |
# |    clip_fraction        | 0.75      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.14     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 280       |
# |    n_updates            | 390       |
# |    policy_gradient_loss | -0.117    |
# |    value_loss           | 581       |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 16         |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 32         |
# | train/                  |            |
# |    approx_kl            | 0.34509814 |
# |    clip_fraction        | 0.7        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5         |
# |    explained_variance   | -1.23e-05  |
# |    learning_rate        | 0.001      |
# |    loss                 | 281        |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.113     |
# |    value_loss           | 583        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 17         |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 34         |
# | train/                  |            |
# |    approx_kl            | 0.41534144 |
# |    clip_fraction        | 0.75       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.86      |
# |    explained_variance   | -2.35e-05  |
# |    learning_rate        | 0.001      |
# |    loss                 | 280        |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.116     |
# |    value_loss           | 580        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 18         |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 36         |
# | train/                  |            |
# |    approx_kl            | 0.42493933 |
# |    clip_fraction        | 0.75       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.63      |
# |    explained_variance   | 1.37e-05   |
# |    learning_rate        | 0.001      |
# |    loss                 | 284        |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.117     |
# |    value_loss           | 589        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 19         |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 38         |
# | train/                  |            |
# |    approx_kl            | 0.33528188 |
# |    clip_fraction        | 0.6        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.4       |
# |    explained_variance   | 2.56e-06   |
# |    learning_rate        | 0.001      |
# |    loss                 | 286        |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.102     |
# |    value_loss           | 594        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 20         |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 40         |
# | train/                  |            |
# |    approx_kl            | 0.52020776 |
# |    clip_fraction        | 0.75       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.54      |
# |    explained_variance   | 2.56e-06   |
# |    learning_rate        | 0.001      |
# |    loss                 | 289        |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.117     |
# |    value_loss           | 598        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 21         |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 42         |
# | train/                  |            |
# |    approx_kl            | 0.41984212 |
# |    clip_fraction        | 0.7        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.67      |
# |    explained_variance   | 9.48e-06   |
# |    learning_rate        | 0.001      |
# |    loss                 | 290        |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.116     |
# |    value_loss           | 601        |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 21        |
# |    iterations           | 22        |
# |    time_elapsed         | 2         |
# |    total_timesteps      | 44        |
# | train/                  |           |
# |    approx_kl            | 0.4228015 |
# |    clip_fraction        | 0.8       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.71     |
# |    explained_variance   | 1.31e-05  |
# |    learning_rate        | 0.001     |
# |    loss                 | 293       |
# |    n_updates            | 460       |
# |    policy_gradient_loss | -0.12     |
# |    value_loss           | 608       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 21        |
# |    iterations           | 23        |
# |    time_elapsed         | 2         |
# |    total_timesteps      | 46        |
# | train/                  |           |
# |    approx_kl            | 0.4431051 |
# |    clip_fraction        | 0.75      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.97     |
# |    explained_variance   | -6.44e-06 |
# |    learning_rate        | 0.001     |
# |    loss                 | 294       |
# |    n_updates            | 470       |
# |    policy_gradient_loss | -0.117    |
# |    value_loss           | 609       |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 24         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 48         |
# | train/                  |            |
# |    approx_kl            | 0.21099743 |
# |    clip_fraction        | 0.7        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.24      |
# |    explained_variance   | -1.1e-05   |
# |    learning_rate        | 0.001      |
# |    loss                 | 294        |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.112     |
# |    value_loss           | 610        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 25         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 50         |
# | train/                  |            |
# |    approx_kl            | 0.20396352 |
# |    clip_fraction        | 0.6        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.34      |
# |    explained_variance   | 6.5e-06    |
# |    learning_rate        | 0.001      |
# |    loss                 | 297        |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.108     |
# |    value_loss           | 616        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 26         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 52         |
# | train/                  |            |
# |    approx_kl            | 0.28831416 |
# |    clip_fraction        | 0.7        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.39      |
# |    explained_variance   | 4.77e-07   |
# |    learning_rate        | 0.001      |
# |    loss                 | 297        |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.114     |
# |    value_loss           | 615        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 27         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 54         |
# | train/                  |            |
# |    approx_kl            | 0.23336756 |
# |    clip_fraction        | 0.65       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.42      |
# |    explained_variance   | -2.5e-06   |
# |    learning_rate        | 0.001      |
# |    loss                 | 296        |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.11      |
# |    value_loss           | 613        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 28         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 56         |
# | train/                  |            |
# |    approx_kl            | 0.15214837 |
# |    clip_fraction        | 0.6        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.48      |
# |    explained_variance   | 1.48e-05   |
# |    learning_rate        | 0.001      |
# |    loss                 | 299        |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.107     |
# |    value_loss           | 620        |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 22        |
# |    iterations           | 29        |
# |    time_elapsed         | 2         |
# |    total_timesteps      | 58        |
# | train/                  |           |
# |    approx_kl            | 0.2171593 |
# |    clip_fraction        | 0.6       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.48     |
# |    explained_variance   | -2.03e-06 |
# |    learning_rate        | 0.001     |
# |    loss                 | 299       |
# |    n_updates            | 530       |
# |    policy_gradient_loss | -0.106    |
# |    value_loss           | 619       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 22        |
# |    iterations           | 30        |
# |    time_elapsed         | 2         |
# |    total_timesteps      | 60        |
# | train/                  |           |
# |    approx_kl            | 0.3532091 |
# |    clip_fraction        | 0.7       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.35     |
# |    explained_variance   | 4.47e-06  |
# |    learning_rate        | 0.001     |
# |    loss                 | 298       |
# |    n_updates            | 540       |
# |    policy_gradient_loss | -0.113    |
# |    value_loss           | 617       |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 31         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 62         |
# | train/                  |            |
# |    approx_kl            | 0.35642225 |
# |    clip_fraction        | 0.65       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.17      |
# |    explained_variance   | 1.53e-05   |
# |    learning_rate        | 0.001      |
# |    loss                 | 299        |
# |    n_updates            | 550        |
# |    policy_gradient_loss | -0.111     |
# |    value_loss           | 619        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 32         |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 64         |
# | train/                  |            |
# |    approx_kl            | 0.44436824 |
# |    clip_fraction        | 0.75       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.87      |
# |    explained_variance   | 2.98e-06   |
# |    learning_rate        | 0.001      |
# |    loss                 | 298        |
# |    n_updates            | 560        |
# |    policy_gradient_loss | -0.118     |
# |    value_loss           | 618        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 21         |
# |    iterations           | 33         |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 66         |
# | train/                  |            |
# |    approx_kl            | 0.42641857 |
# |    clip_fraction        | 0.8        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.21      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.001      |
# |    loss                 | 298        |
# |    n_updates            | 570        |
# |    policy_gradient_loss | -0.12      |
# |    value_loss           | 617        |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 22        |
# |    iterations           | 34        |
# |    time_elapsed         | 3         |
# |    total_timesteps      | 68        |
# | train/                  |           |
# |    approx_kl            | 0.6382648 |
# |    clip_fraction        | 0.7       |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.08     |
# |    explained_variance   | -4.05e-06 |
# |    learning_rate        | 0.001     |
# |    loss                 | 297       |
# |    n_updates            | 580       |
# |    policy_gradient_loss | -0.111    |
# |    value_loss           | 616       |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 35         |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 70         |
# | train/                  |            |
# |    approx_kl            | 0.39841294 |
# |    clip_fraction        | 0.7        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.1       |
# |    explained_variance   | -9.89e-06  |
# |    learning_rate        | 0.001      |
# |    loss                 | 295        |
# |    n_updates            | 590        |
# |    policy_gradient_loss | -0.115     |
# |    value_loss           | 611        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 36          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 72          |
# | train/                  |             |
# |    approx_kl            | 0.009752512 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.51       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.001       |
# |    loss                 | 294         |
# |    n_updates            | 600         |
# |    policy_gradient_loss | 0.0016      |
# |    value_loss           | 610         |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 22        |
# |    iterations           | 37        |
# |    time_elapsed         | 3         |
# |    total_timesteps      | 74        |
# | train/                  |           |
# |    approx_kl            | 0.473949  |
# |    clip_fraction        | 0.65      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.92     |
# |    explained_variance   | -5.96e-06 |
# |    learning_rate        | 0.001     |
# |    loss                 | 292       |
# |    n_updates            | 610       |
# |    policy_gradient_loss | -0.111    |
# |    value_loss           | 605       |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 22          |
# |    iterations           | 38          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 76          |
# | train/                  |             |
# |    approx_kl            | 0.009904087 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | -5.96e-06   |
# |    learning_rate        | 0.001       |
# |    loss                 | 291         |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.000218   |
# |    value_loss           | 603         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 39           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 78           |
# | train/                  |              |
# |    approx_kl            | 0.0006865263 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -2.98e-06    |
# |    learning_rate        | 0.001        |
# |    loss                 | 290          |
# |    n_updates            | 630          |
# |    policy_gradient_loss | -4.2e-05     |
# |    value_loss           | 602          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 22            |
# |    iterations           | 40            |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 80            |
# | train/                  |               |
# |    approx_kl            | 7.6532364e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.2          |
# |    explained_variance   | -1.01e-05     |
# |    learning_rate        | 0.001         |
# |    loss                 | 286           |
# |    n_updates            | 640           |
# |    policy_gradient_loss | -2.78e-05     |
# |    value_loss           | 593           |
# -------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 41         |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 82         |
# | train/                  |            |
# |    approx_kl            | 0.27796686 |
# |    clip_fraction        | 0.4        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.835     |
# |    explained_variance   | -9.54e-07  |
# |    learning_rate        | 0.001      |
# |    loss                 | 284        |
# |    n_updates            | 650        |
# |    policy_gradient_loss | -0.0818    |
# |    value_loss           | 589        |
# ----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 22            |
# |    iterations           | 42            |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 84            |
# | train/                  |               |
# |    approx_kl            | 0.00032895803 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.404        |
# |    explained_variance   | 2.03e-06      |
# |    learning_rate        | 0.001         |
# |    loss                 | 282           |
# |    n_updates            | 660           |
# |    policy_gradient_loss | 1.93e-05      |
# |    value_loss           | 586           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 22            |
# |    iterations           | 43            |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 86            |
# | train/                  |               |
# |    approx_kl            | 1.8537045e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.292        |
# |    explained_variance   | -1.07e-06     |
# |    learning_rate        | 0.001         |
# |    loss                 | 281           |
# |    n_updates            | 670           |
# |    policy_gradient_loss | -3.79e-06     |
# |    value_loss           | 582           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 22            |
# |    iterations           | 44            |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 88            |
# | train/                  |               |
# |    approx_kl            | 1.7881393e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.259        |
# |    explained_variance   | -6.08e-06     |
# |    learning_rate        | 0.001         |
# |    loss                 | 280           |
# |    n_updates            | 680           |
# |    policy_gradient_loss | -4.18e-06     |
# |    value_loss           | 580           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 22            |
# |    iterations           | 45            |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 90            |
# | train/                  |               |
# |    approx_kl            | 2.3841858e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.25         |
# |    explained_variance   | -5.13e-06     |
# |    learning_rate        | 0.001         |
# |    loss                 | 278           |
# |    n_updates            | 690           |
# |    policy_gradient_loss | -1.59e-06     |
# |    value_loss           | 576           |
# -------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 22        |
# |    iterations           | 46        |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 92        |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.243    |
# |    explained_variance   | -4.05e-06 |
# |    learning_rate        | 0.001     |
# |    loss                 | 274       |
# |    n_updates            | 700       |
# |    policy_gradient_loss | -7.63e-07 |
# |    value_loss           | 569       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 22        |
# |    iterations           | 47        |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 94        |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.239    |
# |    explained_variance   | 3.16e-06  |
# |    learning_rate        | 0.001     |
# |    loss                 | 274       |
# |    n_updates            | 710       |
# |    policy_gradient_loss | -6.85e-08 |
# |    value_loss           | 568       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 22        |
# |    iterations           | 48        |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 96        |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.239    |
# |    explained_variance   | -2.03e-06 |
# |    learning_rate        | 0.001     |
# |    loss                 | 273       |
# |    n_updates            | 720       |
# |    policy_gradient_loss | 3.28e-08  |
# |    value_loss           | 566       |
# ---------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 22       |
# |    iterations           | 49       |
# |    time_elapsed         | 4        |
# |    total_timesteps      | 98       |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.238   |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.001    |
# |    loss                 | 273      |
# |    n_updates            | 730      |
# |    policy_gradient_loss | 4.77e-08 |
# |    value_loss           | 566      |
# --------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 22       |
# |    iterations           | 50       |
# |    time_elapsed         | 4        |
# |    total_timesteps      | 100      |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.239   |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.001    |
# |    loss                 | 274      |
# |    n_updates            | 740      |
# |    policy_gradient_loss | 1.25e-07 |
# |    value_loss           | 568      |
# --------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 22        |
# |    iterations           | 51        |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 102       |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.239    |
# |    explained_variance   | -5.13e-06 |
# |    learning_rate        | 0.001     |
# |    loss                 | 271       |
# |    n_updates            | 750       |
# |    policy_gradient_loss | -1.64e-07 |
# |    value_loss           | 562       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 23        |
# |    iterations           | 52        |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 104       |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.238    |
# |    explained_variance   | -1.07e-06 |
# |    learning_rate        | 0.001     |
# |    loss                 | 270       |
# |    n_updates            | 760       |
# |    policy_gradient_loss | 2e-07     |
# |    value_loss           | 560       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 23        |
# |    iterations           | 53        |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 106       |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.236    |
# |    explained_variance   | -2.03e-06 |
# |    learning_rate        | 0.001     |
# |    loss                 | 269       |
# |    n_updates            | 770       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 557       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 23        |
# |    iterations           | 54        |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 108       |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.236    |
# |    explained_variance   | -3.1e-06  |
# |    learning_rate        | 0.001     |
# |    loss                 | 268       |
# |    n_updates            | 780       |
# |    policy_gradient_loss | -9.83e-08 |
# |    value_loss           | 556       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 23        |
# |    iterations           | 55        |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 110       |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.237    |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 268       |
# |    n_updates            | 790       |
# |    policy_gradient_loss | -1.79e-07 |
# |    value_loss           | 556       |
# ---------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 23       |
# |    iterations           | 56       |
# |    time_elapsed         | 4        |
# |    total_timesteps      | 112      |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.238   |
# |    explained_variance   | 2.03e-06 |
# |    learning_rate        | 0.001    |
# |    loss                 | 269      |
# |    n_updates            | 800      |
# |    policy_gradient_loss | 3.25e-07 |
# |    value_loss           | 559      |
# --------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 23       |
# |    iterations           | 57       |
# |    time_elapsed         | 4        |
# |    total_timesteps      | 114      |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.24    |
# |    explained_variance   | 3.1e-06  |
# |    learning_rate        | 0.001    |
# |    loss                 | 267      |
# |    n_updates            | 810      |
# |    policy_gradient_loss | 1.55e-07 |
# |    value_loss           | 555      |
# --------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 23        |
# |    iterations           | 58        |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 116       |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.238    |
# |    explained_variance   | 2.09e-06  |
# |    learning_rate        | 0.001     |
# |    loss                 | 266       |
# |    n_updates            | 820       |
# |    policy_gradient_loss | -1.04e-07 |
# |    value_loss           | 553       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 23        |
# |    iterations           | 59        |
# |    time_elapsed         | 5         |
# |    total_timesteps      | 118       |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.24     |
# |    explained_variance   | -9.54e-07 |
# |    learning_rate        | 0.001     |
# |    loss                 | 267       |
# |    n_updates            | 830       |
# |    policy_gradient_loss | -2e-07    |
# |    value_loss           | 553       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 23        |
# |    iterations           | 60        |
# |    time_elapsed         | 5         |
# |    total_timesteps      | 120       |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.242    |
# |    explained_variance   | -1.07e-06 |
# |    learning_rate        | 0.001     |
# |    loss                 | 267       |
# |    n_updates            | 840       |
# |    policy_gradient_loss | 3.28e-08  |
# |    value_loss           | 555       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 23        |
# |    iterations           | 61        |
# |    time_elapsed         | 5         |
# |    total_timesteps      | 122       |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.244    |
# |    explained_variance   | -2.03e-06 |
# |    learning_rate        | 0.001     |
# |    loss                 | 267       |
# |    n_updates            | 850       |
# |    policy_gradient_loss | -1.01e-07 |
# |    value_loss           | 554       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 23        |
# |    iterations           | 62        |
# |    time_elapsed         | 5         |
# |    total_timesteps      | 124       |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.241    |
# |    explained_variance   | -8.46e-06 |
# |    learning_rate        | 0.001     |
# |    loss                 | 262       |
# |    n_updates            | 860       |
# |    policy_gradient_loss | -3.49e-07 |
# |    value_loss           | 545       |
# ---------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 23       |
# |    iterations           | 63       |
# |    time_elapsed         | 5        |
# |    total_timesteps      | 126      |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.237   |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.001    |
# |    loss                 | 261      |
# |    n_updates            | 870      |
# |    policy_gradient_loss | 1.01e-07 |
# |    value_loss           | 542      |
# --------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 23        |
# |    iterations           | 64        |
# |    time_elapsed         | 5         |
# |    total_timesteps      | 128       |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.235    |
# |    explained_variance   | 4.23e-06  |
# |    learning_rate        | 0.001     |
# |    loss                 | 261       |
# |    n_updates            | 880       |
# |    policy_gradient_loss | -6.56e-08 |
# |    value_loss           | 543       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 23        |
# |    iterations           | 65        |
# |    time_elapsed         | 5         |
# |    total_timesteps      | 130       |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.238    |
# |    explained_variance   | 6.26e-06  |
# |    learning_rate        | 0.001     |
# |    loss                 | 264       |
# |    n_updates            | 890       |
# |    policy_gradient_loss | -6.56e-08 |
# |    value_loss           | 549       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 23        |
# |    iterations           | 66        |
# |    time_elapsed         | 5         |
# |    total_timesteps      | 132       |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.242    |
# |    explained_variance   | 2.09e-06  |
# |    learning_rate        | 0.001     |
# |    loss                 | 265       |
# |    n_updates            | 900       |
# |    policy_gradient_loss | -2.68e-07 |
# |    value_loss           | 550       |
# ---------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 23       |
# |    iterations           | 67       |
# ...
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00317 |
# |    explained_variance   | 1.19e-07 |
# |    learning_rate        | 0.001    |
# |    loss                 | 0.0383   |
# |    n_updates            | 33380    |
# |    policy_gradient_loss | 0        |
# |    value_loss           | 0.295    |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 219      |
# |    ep_rew_mean          | 3.42e+03 |
# | time/                   |          |
# |    fps                  | 25       |
# |    iterations           | 3315     |
# |    time_elapsed         | 259      |
# |    total_timesteps      | 6630     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00316 |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.001    |
# |    loss                 | 0.0464   |
# |    n_updates            | 33390    |
# |    policy_gradient_loss | 0        |
# |    value_loss           | 0.4      |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 219      |
# |    ep_rew_mean          | 3.42e+03 |
# | time/                   |          |
# |    fps                  | 25       |
# |    iterations           | 3316     |
# |    time_elapsed         | 259      |
# |    total_timesteps      | 6632     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00318 |
# |    explained_variance   | 1.19e-07 |
# |    learning_rate        | 0.001    |
# |    loss                 | 0.0421   |
# |    n_updates            | 33400    |
# |    policy_gradient_loss | 0        |
# |    value_loss           | 0.314    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 219       |
# |    ep_rew_mean          | 3.42e+03  |
# | time/                   |           |
# |    fps                  | 25        |
# |    iterations           | 3317      |
# |    time_elapsed         | 259       |
# |    total_timesteps      | 6634      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00318  |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 0.0295    |
# |    n_updates            | 33410     |
# |    policy_gradient_loss | -2.29e-07 |
# |    value_loss           | 0.255     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 219      |
# |    ep_rew_mean          | 3.42e+03 |
# | time/                   |          |
# |    fps                  | 25       |
# |    iterations           | 3318     |
# |    time_elapsed         | 259      |
# |    total_timesteps      | 6636     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00316 |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.001    |
# |    loss                 | 0.032    |
# |    n_updates            | 33420    |
# |    policy_gradient_loss | 1.22e-07 |
# |    value_loss           | 0.166    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 219       |
# |    ep_rew_mean          | 3.42e+03  |
# | time/                   |           |
# |    fps                  | 25        |
# |    iterations           | 3319      |
# |    time_elapsed         | 259       |
# |    total_timesteps      | 6638      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00315  |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 0.0241    |
# |    n_updates            | 33430     |
# |    policy_gradient_loss | -1.97e-07 |
# |    value_loss           | 0.103     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 219      |
# |    ep_rew_mean          | 3.42e+03 |
# | time/                   |          |
# |    fps                  | 25       |
# |    iterations           | 3320     |
# |    time_elapsed         | 260      |
# |    total_timesteps      | 6640     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00314 |
# |    explained_variance   | 1.79e-07 |
# |    learning_rate        | 0.001    |
# |    loss                 | 0.0146   |
# |    n_updates            | 33440    |
# |    policy_gradient_loss | 0        |
# |    value_loss           | 0.0806   |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 219       |
# |    ep_rew_mean          | 3.42e+03  |
# | time/                   |           |
# |    fps                  | 25        |
# |    iterations           | 3321      |
# |    time_elapsed         | 260       |
# |    total_timesteps      | 6642      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00311  |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 0.0162    |
# |    n_updates            | 33450     |
# |    policy_gradient_loss | -1.43e-07 |
# |    value_loss           | 0.0426    |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 219      |
# |    ep_rew_mean          | 3.42e+03 |
# | time/                   |          |
# |    fps                  | 25       |
# |    iterations           | 3322     |
# |    time_elapsed         | 260      |
# |    total_timesteps      | 6644     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00311 |
# |    explained_variance   | 4.17e-07 |
# |    learning_rate        | 0.001    |
# |    loss                 | 0.00967  |
# |    n_updates            | 33460    |
# |    policy_gradient_loss | 0        |
# |    value_loss           | 0.0353   |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 219      |
# |    ep_rew_mean          | 3.42e+03 |
# | time/                   |          |
# |    fps                  | 25       |
# |    iterations           | 3323     |
# |    time_elapsed         | 260      |
# |    total_timesteps      | 6646     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00311 |
# |    explained_variance   | 1.73e-06 |
# |    learning_rate        | 0.001    |
# |    loss                 | 0.00117  |
# |    n_updates            | 33470    |
# |    policy_gradient_loss | 0        |
# |    value_loss           | 0.00279  |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 219      |
# |    ep_rew_mean          | 3.42e+03 |
# | time/                   |          |
# |    fps                  | 25       |
# |    iterations           | 3324     |
# |    time_elapsed         | 260      |
# |    total_timesteps      | 6648     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00311 |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.001    |
# |    loss                 | 0.00487  |
# |    n_updates            | 33480    |
# |    policy_gradient_loss | 4.17e-07 |
# |    value_loss           | 0.0119   |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 219      |
# |    ep_rew_mean          | 3.42e+03 |
# | time/                   |          |
# |    fps                  | 25       |
# |    iterations           | 3325     |
# |    time_elapsed         | 260      |
# |    total_timesteps      | 6650     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00312 |
# |    explained_variance   | 1.79e-07 |
# |    learning_rate        | 0.001    |
# |    loss                 | 0.0282   |
# |    n_updates            | 33490    |
# |    policy_gradient_loss | 0        |
# |    value_loss           | 0.195    |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 219      |
# |    ep_rew_mean          | 3.42e+03 |
# | time/                   |          |
# |    fps                  | 25       |
# |    iterations           | 3326     |
# |    time_elapsed         | 260      |
# |    total_timesteps      | 6652     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00311 |
# |    explained_variance   | 1.19e-07 |
# |    learning_rate        | 0.001    |
# |    loss                 | 0.0195   |
# |    n_updates            | 33500    |
# |    policy_gradient_loss | 1.31e-07 |
# |    value_loss           | 0.157    |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 219      |
# |    ep_rew_mean          | 3.42e+03 |
# | time/                   |          |
# |    fps                  | 25       |
# |    iterations           | 3327     |
# |    time_elapsed         | 260      |
# |    total_timesteps      | 6654     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00312 |
# |    explained_variance   | 5.96e-08 |
# |    learning_rate        | 0.001    |
# |    loss                 | 0.047    |
# |    n_updates            | 33510    |
# |    policy_gradient_loss | 0        |
# |    value_loss           | 0.415    |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 219      |
# |    ep_rew_mean          | 3.42e+03 |
# | time/                   |          |
# |    fps                  | 25       |
# |    iterations           | 3328     |
# |    time_elapsed         | 260      |
# |    total_timesteps      | 6656     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00311 |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.001    |
# |    loss                 | 0.0401   |
# |    n_updates            | 33520    |
# |    policy_gradient_loss | 0        |
# |    value_loss           | 0.427    |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 219      |
# |    ep_rew_mean          | 3.42e+03 |
# | time/                   |          |
# |    fps                  | 25       |
# |    iterations           | 3329     |
# |    time_elapsed         | 260      |
# |    total_timesteps      | 6658     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00311 |
# |    explained_variance   | 5.96e-08 |
# |    learning_rate        | 0.001    |
# |    loss                 | 0.0557   |
# |    n_updates            | 33530    |
# |    policy_gradient_loss | 0        |
# |    value_loss           | 0.554    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 219       |
# |    ep_rew_mean          | 3.42e+03  |
# | time/                   |           |
# |    fps                  | 25        |
# |    iterations           | 3330      |
# |    time_elapsed         | 260       |
# |    total_timesteps      | 6660      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00311  |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.001     |
# |    loss                 | 0.0912    |
# |    n_updates            | 33540     |
# |    policy_gradient_loss | -1.19e-07 |
# |    value_loss           | 0.699     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 219      |
# |    ep_rew_mean          | 3.42e+03 |
# | time/                   |          |
# |    fps                  | 25       |
# |    iterations           | 3331     |
# |    time_elapsed         | 260      |
# |    total_timesteps      | 6662     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00312 |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.001    |
# |    loss                 | 0.148    |
# |    n_updates            | 33550    |
# |    policy_gradient_loss | 8.94e-08 |
# |    value_loss           | 0.952    |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 219      |
# |    ep_rew_mean          | 3.42e+03 |
# | time/                   |          |
# |    fps                  | 25       |
# |    iterations           | 3332     |
# |    time_elapsed         | 260      |
# |    total_timesteps      | 6664     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00312 |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.001    |
# |    loss                 | 0.176    |
# |    n_updates            | 33560    |
# |    policy_gradient_loss | 0        |
# |    value_loss           | 1.06     |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 219      |
# |    ep_rew_mean          | 3.42e+03 |
# | time/                   |          |
# |    fps                  | 25       |
# |    iterations           | 3333     |
# |    time_elapsed         | 260      |
# |    total_timesteps      | 6666     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00313 |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.001    |
# |    loss                 | 0.176    |
# |    n_updates            | 33570    |
# |    policy_gradient_loss | 0        |
# |    value_loss           | 1.06     |
# --------------------------------------

# %% [markdown]
# ### Important notes
#
# A few notes here:
# - the meta parameters ("net_arch", "learning_rate", "n_steps", "gamma", "batch_size", ...) are not fine tuned and are unlikely to lead to good results
# - the number of training steps is way too low (it should be much greater, probably in >= 1M)
# - there is no "heuristics" embeded here. Agents performs best when they act only when the grid is "in danger" (otherwise it takes a while for an agent to learn to "do nothing")
# - we use a "test" environment, this is why we specified "test=True" at the environment creation.
# - observations are not scaled
# - reward is not tuned for a particular goal: default reward is used and this might not be a good things to do for the particular agent we are trying to build.
#
# All of these probably lead to a quite terrible agent...
#
# ### Other important notes
#
# We do not recommend to train "real" model with such simple features. In particular, you might need to save (at different stage of training) your agent, log the progress using tensorboard (for example) etc.
#
# This can be done with "callbacks" here that are not covered in this "getting started".
#
#
# ### Yet another important note
# If you chose to use "l2rpn baselines" it will be as easy to learn an agent taking into account account all of the above if you us:
#
# ```python
# from l2rpn_baselines.utils import GymEnvWithRecoWithDN
# from l2rpn_baselines.PP0_SB3 import train
# ```
#
# You can have a look at the "examples" section of the l2rpn baselines repository (https://github.com/grid2op/l2rpn-baselines/tree/master/examples)

# %% [markdown]
# ## III) Evaluating the Agent

# %% [markdown]
# And now, it is time to test the agent that we trained on different scenarios (ideally) using another environment (to mimic a real process)
#
# To do that, we have two main choices:
# 1) we use the trained model, convert the other environment to a gym env, run the environment and ask for the neural network what it should od
# 2) embed the trained neural network in a "grid2op agent" class and use the built grid2op runner transparently
#
# Solution 1) is to be preferred for "quick and dirty" tests. In all other cases we strongly recommend to use solution 2 as it also allows you to not recode the "gym loop" to benefit from the saving functionality (as so to be able to inspect your agent in grid2viz for example) etc.
#
# We will code a minimal agent to leverage solution 2. As always, this is much easier to use with l2rpn_baselines package...
#
# ### III A) Create the "grid2op agent"

# %%
from grid2op.Agent import BaseAgent

class MyPPOAgent(BaseAgent):
    def __init__(self,
                 action_space,  # grid2op action space
                 used_trained_gym_env,  # gym env used for training
                 trained_ppo_nnet,  # neural net after training
                 ):
        super().__init__(action_space)
        self.nn_model = trained_ppo_nnet
        self.gym_env = used_trained_gym_env
    
    def act(self, observation, reward, done=False):
        gym_obs = self.gym_env.observation_space.to_gym(observation)
        gym_act, _ = self.nn_model.predict(gym_obs, deterministic=True)
        grid2op_act = self.gym_env.action_space.from_gym(gym_act)
        return grid2op_act
    
my_agent = MyPPOAgent(training_env.action_space, gym_env, nn_model)

# %% [markdown]
# **NB** Of course, if you use "l2rpn_baselines" you are not forced to recode it. Everything is properly set up for you to use directly the "trained l2rpn_baselines agent" in the grid2op runner !

# %% [markdown]
# ### III.B) Perform the evaluation
#
# Now we create the test environment (in this case it's the same as the training one, but we really do recommend to have different environment with different data...)
#
# For a real experiment this could look like:
#
# ```python
# training_env = grid2op.make(env_name+"_test", ...)
# ```

# %%
testing_env = grid2op.make(env_name, test=True, backend=bk_cls())
# Out:
# c:\Users\admin\Grid2Op\venv_g2op\lib\site-packages\grid2op\MakeEnv\Make.py:454: UserWarning: You are using a development environment. This environment is not intended for training agents. It might not be up to date and its primary use if for tests (hence the "test=True" you passed as argument). Use at your own risk.
#   warnings.warn(_MAKE_DEV_ENV_WARN)

# %%
import shutil
from tqdm.notebook import tqdm
from grid2op.Runner import Runner
from grid2op.Episode import EpisodeData

save_path = "saved_agent_PPO_{}".format(LEARNING_ITERATION)
path_save_results = "{}_results".format(save_path)
shutil.rmtree(path_save_results, ignore_errors=True)

test_runner = Runner(**testing_env.get_params_for_runner(),
                     agentInstance=my_agent, agentClass=None)
res = test_runner.run(nb_episode=EVAL_EPISODE,
                      max_iter=MAX_EVAL_STEPS,
                      pbar=tqdm,
                      path_save=f"./{path_save_results}")
# Out:
# episode:   0%|          | 0/1 [00:00<?, ?it/s]
# episode:   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# ### III.B) Inspect the Agent

# %% [markdown]
# Please refer to the official documentation for more information about the contents of the directory where the data is saved. Note that saving the information is triggered by the "path_save" argument of the "runner.run" function.
#
# The information contained in this output will be saved in a structured way and includes :
# For each episode :
#   - "episode_meta.json": json file that represents some meta information about:
#
#     - "backend_type": the name of the `grid2op.Backend` class used
#     - "chronics_max_timestep": the **maximum** number of timesteps for the chronics used
#     - "chronics_path": the path where the temporal data (chronics) are located
#     - "env_type": the name of the `grid2op.Environment` class used.
#     - "grid_path": the path where the powergrid has been loaded from
#
#   - "episode_times.json": json file that gives some information about the total time spent in multiple parts of the runner, mainly the
#     `grid2op.Agent` (and especially its method `grid2op.Agent.act`) and the
#     `grid2op.Environment`
#
#   - "_parameters.json": json representation of the `grid2op.Parameters` used for this episode
#   - "rewards.npy": numpy 1d-array giving the rewards at each time step. We adopted the convention that the stored
#     reward at index `i` is the one observed by the agent at time `i` and **NOT** the reward sent by the
#     `grid2op.Environment` after the action has been taken.
#   - "exec_times.npy": numpy 1d-array giving the execution time for each time step in the episode
#   - "actions.npy": numpy 2d-array giving the actions that have been taken by the `grid2op.Agent`. At row `i` of "actions.npy" is a
#     vectorized representation of the action performed by the agent at timestep `i` *ie.* **after** having observed
#     the observation present at row `i` of "observation.npy" and the reward showed in row `i` of "rewards.npy".
#   - "disc_lines.npy": numpy 2d-array that tells which lines have been disconnected during the simulation of the cascading failure at each
#     time step. The same convention has been adopted for "rewards.npy". This means that the powerlines are
#     disconnected when the `grid2op.Agent` takes the `grid2op.Action` at time step `i`.
#   - "observations.npy": numpy 2d-array representing the `grid2op.Observation` at the disposal of the
#     `grid2op.Agent` when he took his action.

# %% [markdown]
# We can first look at the repository were the data is stored:

# %%
import os
os.listdir(path_save_results)
# Out:
# ['2019-01-12',
#  'dict_action_space.json',
#  'dict_attack_space.json',
#  'dict_env_modification_space.json',
#  'dict_observation_space.json']

# %% [markdown]
# As we can see there are 2 folders, each corresponding to a chronics.
# There are also additional json files.
#
# Now let's see what is inside one of these folders:

# %%
EpisodeData.list_episode(path_save_results)
# Out:
# [('c:\\Users\\admin\\Grid2Op\\getting_started\\saved_agent_PPO_50_results',
#   '2019-01-12')]

# %% [markdown]
# For example, we can load the actions chosen by the Agent, and have a look at them.
#
# To do that, we will load the action array and use the `action_space` function to convert it back to `Action` objects.

# %%
all_episodes = EpisodeData.list_episode(path_save_results)
this_episode = EpisodeData.from_disk(*all_episodes[0])
li_actions = this_episode.actions

# %% [markdown]
# This allows us to have a deeper look at the actions, and their effects.

# %% [markdown]
# Now we will inspect the actions that has been taken by the agent :

# %%
line_disc = 0
line_reco = 0
for act in li_actions:
    dict_ = act.as_dict()
    if "set_line_status" in dict_:
        line_reco +=  dict_["set_line_status"]["nb_connected"]
        line_disc +=  dict_["set_line_status"]["nb_disconnected"]
print(f'Total reconnected lines : {line_reco}')
print(f'Total disconnected lines : {line_disc}')
# Out:
# Total reconnected lines : 0
# Total disconnected lines : 0

# %% [markdown]
# As we can see, during this episode, our agent never tries to disconnect or reconnect a line.

# %% [markdown]
# We can also analyse the observations of the recorded episode :

# %%
li_observations = this_episode.observations
nb_real_disc = 0
for obs_ in li_observations:
    nb_real_disc += (obs_.line_status == False).sum()
print(f'Total number of disconnected powerlines cumulated over all the timesteps : {nb_real_disc}')
# Out:
# Total number of disconnected powerlines cumulated over all the timesteps : 0

# %% [markdown]
# We can also look at the kind of actions that the agent chose:

# %%
actions_count = {}
for act in li_actions:
    act_as_vect = tuple(act.to_vect())
    if not act_as_vect in actions_count:
        actions_count[act_as_vect] = 0
    actions_count[act_as_vect] += 1
print("The agent did {} different valid actions.".format(len(actions_count)))
# Out:
# The agent did 1 different valid actions.

# %% [markdown]
# The actions chosen by the agent were :

# %%
for act in li_actions:
    print(act)
# Out:
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - NOT switch anything in the topology
# 	 - NOT force any particular bus configuration
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - NOT switch anything in the topology
# 	 - NOT force any particular bus configuration
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - NOT switch anything in the topology
# 	 - NOT force any particular bus configuration
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - NOT switch anything in the topology
# 	 - NOT force any particular bus configuration
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - NOT switch anything in the topology
# 	 - NOT force any particular bus configuration
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - NOT switch anything in the topology
# 	 - NOT force any particular bus configuration
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - NOT switch anything in the topology
# 	 - NOT force any particular bus configuration
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - NOT switch anything in the topology
# 	 - NOT force any particular bus configuration
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - NOT switch anything in the topology
# 	 - NOT force any particular bus configuration
# This action will:
# 	 - NOT change anything to the injections
# 	 - NOT perform any redispatching action
# 	 - NOT modify any storage capacity
# 	 - NOT perform any curtailment
# 	 - NOT force any line status
# 	 - NOT switch any line status
# 	 - NOT switch anything in the topology
# 	 - NOT force any particular bus configuration

# %% [markdown]
# ## IV) Improve your Agent
#
# As we stated above, the goal of this notebook was not to show a "state of the art" agent but rather to explain with a "minimal example" how you could get started into training an agent operating a powergrid.
#
# To improve your agent, we strongly recommend to use the l2rpn_baselines repository, to fine tune the hyper parameters of your agents, to train it for longer on more diverse data, to use a different RL algorithm (maybe PPO is not the best one for this environment ?) etc. etc.
#
# Using some pre training (for example training the policy in a supervised fashion using heuristic of human demonstration data) might be a good solution.
#
# Another promising tool would be to use some "curiculum learning" where, at the beginning, the agent would interact with a simplified version of the environment (easier rules, no disconnection due to overflow, no cooldown after an action has been made,  etc.) and after some time, when the agent is starting to perform well to increase this difficulty.
#
# Yet another possibility would be to access some kind of "model based" reinforcement learning, such as alpha-* models (*eg* alpha go).

# %%
import torch
print(torch.__version__)
# Out:
# 2.6.0+cu126
